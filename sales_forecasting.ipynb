# %%
# 📊 Sales Forecasting Using Prophet

# STEP 1: Install Prophet
# !pip install prophet

# STEP 2: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet

# STEP 3: Generate synthetic sales data (for demo purposes)
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', freq='D')
sales = 100 + 10 * np.arange(len(date_range)) + np.random.normal(0, 50, size=len(date_range))
data = pd.DataFrame({'Date': date_range, 'Sales': sales})

# STEP 4: Save the data (optional)
data.to_csv('sample-sales-data.csv', index=False)

# STEP 5: Prepare Data for Prophet
df = data.rename(columns={'Date': 'ds', 'Sales': 'y'})

# STEP 6: Create and Train Prophet Model
model = Prophet()
model.fit(df)

# STEP 7: Make Future Predictions
future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)

# STEP 8: Plot Forecast
fig1 = model.plot(forecast)
plt.title("📈 Sales Forecast (Next 30 Days)")
plt.show()

# STEP 9: Plot Forecast Components (Trend/Seasonality)
fig2 = model.plot_components(forecast)
plt.show()
# Out:
# ...
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpp4ulz14s/d2ysch58.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpp4ulz14s/7kw6_sne.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56637', 'data', 'file=/tmp/tmpp4ulz14s/d2ysch58.json', 'init=/tmp/tmpp4ulz14s/7kw6_sne.json', 'output', 'file=/tmp/tmpp4ulz14s/prophet_modelygns9myk/prophet_model-20250524153508.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:35:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:35:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ...
